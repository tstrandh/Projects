# %% [markdown]
# ## Introduction / Business Problem
# A Toronto-based beer brewery recently started bottling its beer. Instead of using a distributor to sell and deliver beer to stores in Toronto, the brewery decided to distribute its beer independently. Since the brewery is young, the owner decided only to distribute to on-premise accounts (places where beer is sold and consumed "on-premise", namely restaurants, as opposed to grocery and convenience stores which are "off-premise" accounts). The brewery is also constrained by owning only one delivery truck which is not refrigerated. In order to maintain a quality product, the owner does not want to distrubute further than 5 kilometers (km) from the brewery in an unrefrigerated truck.
#
# The owner does not have any confirmed accounts yet, but he wants to understand what a delivery route would look like if he has the capacity to supply 50 stores within a 5 km radius of brewery with one delivery per week. The owner wants to filter this projected route based on the most popular 50 on-premise stores within the search area. The end product will be a map with 50 store points segmented into clusters and color-coded by delivery day of the week (Monday through Friday).
#
# The target audience for this data is business owners, distributors, and sales representatives who want to optimize their route selection for sales and delivery of their products. Routes can be filtered and refined in numerous ways to meet the needs of the specific customer. In this case a brewery owner is trying to understand distribution routes for his product with a limited delivery capacity.
#
# ## Data Methodology
# The data I will need for this project will come from Foursquare API. I will filter search results by the following criteria: within 5 km of the brewery; only include "restaurant" in search query; and pick the top 50 venues. Once the data points have been collected, I will segment the stores into 5 geographic clusters, one for each day of the week (Monday through Friday). The clusters will define the separate routes for the one delivery truck each day (the stores only receive one delivery per week).
#
# While the data is based on a maximum location search radius, it is also defined by popular restaurants within the search area. This may result in data points are that not evenly spread across the search area. This is okay, as the intent is to sell the product to the most popular places, not evenly across the the 10 miles. An example of a single day route would be a color-coded cluster of 10 stores in a 5 blocks area of downtown Toronto. A second cluster may be two blocks away or it could be one mile away in a separate neighborhood.
#
# The method for clustering the data points and displaying them on a map, color-coded by delivery day of the week, will follow the functions we have already practiced in this course.

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# #### Load necessary libraries

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

from IPython.display import Image 
from IPython.core.display import HTML 
    
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium

import matplotlib.cm as cm
import matplotlib.colors as colors

print('Folium installed')
print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geopy-1.21.0               |             py_0          58 KB  conda-forge
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          92 KB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib: 1.50-py_0   conda-forge
#     geopy:         1.21.0-py_0 conda-forge
#
#
# Downloading and Extracting Packages
# geopy-1.21.0         | 58 KB     | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: | ^C
# failed
#
# CondaError: KeyboardInterrupt
#
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = 'FZRTE5WPMVWLLLYJTWJYWIIUEKCPZKQPZRZR4H2BHI5NWWYP' # your Foursquare ID
CLIENT_SECRET = 'GI20Q4VR3PMGVOCDJ0LMO0J2DGM2MIOF2NHJX4E1G3PHBMFC' # your Foursquare Secret
VERSION = '20180604'
print('Your credentials:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentials:
# CLIENT_ID: FZRTE5WPMVWLLLYJTWJYWIIUEKCPZKQPZRZR4H2BHI5NWWYP
# CLIENT_SECRET:GI20Q4VR3PMGVOCDJ0LMO0J2DGM2MIOF2NHJX4E1G3PHBMFC

# %% [markdown]
# #### Find coordinates for our brewery and assign them to lat/long

# %% [markdown]
# #### The example brewery in this project will use location data for Steam Whistle Brewing, located in downtown Toronto at 255 Bremner Boulevard.

# %%
address = '255 Bremner Boulevard, Toronto'

geolocator = Nominatim(user_agent="my_app")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinates the brewery are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinates the brewery are 43.6409668, -79.3851702.

# %% [markdown]
# #### Search within 5 km of the brewery for restaurants

# %%
search_query = 'restaurant'
LIMIT = 50
radius = 5000
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=FZRTE5WPMVWLLLYJTWJYWIIUEKCPZKQPZRZR4H2BHI5NWWYP&client_secret=GI20Q4VR3PMGVOCDJ0LMO0J2DGM2MIOF2NHJX4E1G3PHBMFC&ll=43.6409668,-79.3851702&v=20180604&query=restaurant&radius=5000&limit=50'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5eac579bf7706a001b1b2b92'},
#  'response': {'venues': [{'id': '4ad4c05cf964a520dff520e3',
#     'name': '360 Restaurant',
#     'location': {'address': '301 Front St W',
#      'crossStreet': '301 Front St. W',
#      'lat': 43.642537317144566,
#      'lng': -79.38704201569328,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.642537317144566,
#        'lng': -79.38704201569328}],
#      'distance': 230,
#      'postalCode': 'M5V 2T6',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['301 Front St W (301 Front St. W)',
#       'Toronto ON M5V 2T6',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d123941735',
#       'name': 'Wine Bar',
#       'pluralName': 'Wine Bars',
#       'shortName': 'Wine Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588352904',
#     'hasPerk': False},
#    {'id': '4ad4c060f964a5208af720e3',
#     'name': 'Arriba Restaurant',
#     'location': {'address': '1 Blue Jays Way',
#      'crossStreet': 'inside the Renaissance Hotel',
#      'lat': 43.641479256282814,
#      'lng': -79.38907384872437,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.641479256282814,
#        'lng': -79.38907384872437}],
#      'distance': 319,
#      'postalCode': 'M5V 1J4',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['1 Blue Jays Way (inside the Renaissance Hotel)',
#       'Toronto ON M5V 1J4',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '68079429'},
#     'referralId': 'v-1588352904',
#     'hasPerk': False},
#    {'id': '4aef8854f964a5201cd921e3',
#     'name': 'Aroma Fine Indian Restaurant',
#     'location': {'address': '287 King St. W',
#      'crossStreet': 'at John St.',
#      'lat': 43.646462521503445,
#      'lng': -79.38964414801342,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.646462521503445,
#        'lng': -79.38964414801342}],
#      'distance': 710,
#      'postalCode': 'M5V 1J5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['287 King St. W (at John St.)',
#       'Toronto ON M5V 1J5',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588352904',
#     'hasPerk': False},
#    {'id': '4bc3ad5e461576b0db037f32',
#     'name': 'Sightlines Restaurant',
#     'location': {'address': 'Rogers Centre',
#      'lat': 43.641635072211194,
#      'lng': -79.38936460164057,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.641635072211194,
#        'lng': -79.38936460164057}],
#      'distance': 345,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Rogers Centre', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'shortName': 'American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588352904',
#     'hasPerk': False},
#    {'id': '4b223f5af964a520ba4424e3',
#     'name': 'Azure Restaurant & Bar',
#     'location': {'address': '225 Front St W',
#      'crossStreet': 'in InterContinental Toronto Centre',
#      'lat': 43.644749195919346,
#      'lng': -79.38511295085902,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.644749195919346,
#        'lng': -79.38511295085902}],
#      'distance': 421,
#      'postalCode': 'M5V 2X3',
#      'cc': 'CA',
#      'neighborhood': 'Entertainment District',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['225 Front St W (in InterContinental Toronto Centre)',
#       'Toronto ON M5V 2X3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '136175835'},
#     'referralId': 'v-1588352904',
#     'hasPerk': False},
#    {'id': '4ad4c05df964a5203ff620e3',
#     'name': 'Victor Restaurant & Bar',
#     'location': {'address': '30 Mercer Street',
#      'crossStreet': 'at John St',
#      'lat': 43.64563436248102,
#      'lng': -79.39112538566908,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64563436248102,
#        'lng': -79.39112538566908}],
#      'distance': 707,
#      'postalCode': 'M5V 1H3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['30 Mercer Street (at John St)',
#       'Toronto ON M5V 1H3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588352904',
#     'hasPerk': False},
#    {'id': '4ada5d5bf964a520e92121e3',
#     'name': 'The Hot House Restaurant & Bar',
#     'location': {'address': '35 Church St',
#      'crossStreet': 'at Front St E',
#      'lat': 43.64882370529773,
#      'lng': -79.37370210886002,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64882370529773,
#        'lng': -79.37370210886002}],
#      'distance': 1272,
#      'postalCode': 'M5E 1T3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['35 Church St (at Front St E)',
#       'Toronto ON M5E 1T3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'shortName': 'American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588352904',
#     'hasPerk': False},
#    {'id': '4b072e9df964a52009f922e3',
#     'name': 'Sky Dragon Chinese Restaurant 龍翔酒樓',
#     'location': {'address': '280 Spadina Ave.',
#      'crossStreet': 'at Dundas St. W.',
#      'lat': 43.65278331265585,
#      'lng': -79.39817372355205,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65278331265585,
#        'lng': -79.39817372355205}],
#      'distance': 1681,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['280 Spadina Ave. (at Dundas St. W.)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1f5931735',
#       'name': 'Dim Sum Restaurant',
#       'pluralName': 'Dim Sum Restaurants',
#       'shortName': 'Dim Sum',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dimsum_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588352904',
#     'hasPerk': False},
#    {'id': '4ad4c05cf964a52006f620e3',
#     'name': "Victoria's Restaurant",
#     'location': {'address': '37 King Street East',
#      'crossStreet': 'at Le Meridien King Edward Hotel',
#      'lat': 43.64929834396347,
#      'lng': -79.37643067251867,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64929834396347,
#        'lng': -79.37643067251867}],
#      'distance': 1164,
#      'postalCode': 'M5C 1E9',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['37 King Street East (at Le Meridien King Edward Hotel)',
#       'Toronto ON M5C 1E9',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '498556908'},
#     'referralId': 'v-1588352904',
#     'hasPerk': False},
#    {'id': '4ad4c05ff964a52048f720e3',
#     'name': 'Hemispheres Restaurant & Bistro',
#     'location': {'address': '110 Chestnut Street',
#      'lat': 43.65488413420439,
#      'lng': -79.38593077371578,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65488413420439,
#        'lng': -79.38593077371578}],
#      'distance': 1550,
#      'postalCode': 'M5G 1R3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['110 Chestnut Street',
#       'Toronto ON M5G 1R3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'shortName': 'American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588352904',
#     'hasPerk': False},
#    {'id': '4b266f05f964a520657b24e3',
#     'name': 'Goldstone Noodle Restaurant 金石',
#     'location': {'address': '266 Spadina Ave',
#      'crossStreet': 'at Willison Sq',
#      'lat': 43.6522783893466,
#      'lng': -79.39803917534071,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6522783893466,
#        'lng': -79.39803917534071}],
#      'distance': 1630,
#      'postalCode': 'M5T 2E4',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['266 Spadina Ave (at Willison Sq)',
#       'Toronto ON M5T 2E4',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1d1941735',
#       'name': 'Noodle House',
#       'pluralName': 'Noodle Houses',
#       'shortName': 'Noodles',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588352904',
#     'hasPerk': False},
#    {'id': '562922be498e2c6aad0e6091',
#     'name': 'Evviva Restaurant',
#     'location': {'address': '25 Lower Simcoe St',
#      'crossStreet': 'Grand Trunk Cresc',
#      'lat': 43.64157991761808,
#      'lng': -79.38345644030795,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64157991761808,
#        'lng': -79.38345644030795}],
#      'distance': 154,
#      'postalCode': 'M5J 3A1',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['25 Lower Simcoe St (Grand Trunk Cresc)',
#       'Toronto ON M5J 3A1',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d146941735',
#       'name': 'Deli / Bodega',
#       'pluralName': 'Delis / Bodegas',
#       'shortName': 'Deli / Bodega',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588352904',
#     'hasPerk': False},
#    {'id': '4ad4c060f964a5207ff720e3',
#     'name': 'Rol San Restaurant 龍笙棧',
#     'location': {'address': '323 Spadina Ave.',
#      'crossStreet': "at D'Arcy St.",
#      'lat': 43.65431754076345,
#      'lng': -79.39864998374682,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65431754076345,
#        'lng': -79.39864998374682}],
#      'distance': 1840,
#      'postalCode': 'M5T 2E9',
#      'cc': 'CA',
#      'neighborhood': 'Kensington Market',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ["323 Spadina Ave. (at D'Arcy St.)",
#       'Toronto ON M5T 2E9',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1f5931735',
#       'name': 'Dim Sum Restaurant',
#       'pluralName': 'Dim Sum Restaurants',
#       'shortName': 'Dim Sum',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dimsum_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588352904',
#     'hasPerk': False},
#    {'id': '4c47d78c1ddec92817ca9e32',
#     'name': "Micheal's Restaurant and Deli",
#     'location': {'address': '566 Queen St W',
#      'lat': 43.647289322295066,
#      'lng': -79.40349333397708,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.647289322295066,
#        'lng': -79.40349333397708}],
#      'distance': 1635,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['566 Queen St W', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588352904',
#     'hasPerk': False},
#    {'id': '5c33c7cd8194fc002c66f72e',
#     'name': 'Green Tea Restaurant Downtown',
#     'location': {'address': '261 Spadina Avenue. Upper level',
#      'lat': 43.652487830335545,
#      'lng': -79.39750134944916,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.652487830335545,
#        'lng': -79.39750134944916}],
#      'distance': 1622,
#      'postalCode': 'M5T 2E3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['261 Spadina Avenue. Upper level',
#       'Toronto ON M5T 2E3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588352904',
#     'hasPerk': False},
#    {'id': '501d4d55e4b0825080212f3c',
#     'name': 'Gonoe Sushi Japanese Restaurant',
#     'location': {'address': '262 Queens Quay W',
#      'lat': 43.63901430970685,
#      'lng': -79.38591360078077,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.63901430970685,
#        'lng': -79.38591360078077}],
#      'distance': 225,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['262 Queens Quay W', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'shortName': 'Sushi',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588352904',
#     'hasPerk': False},
#    {'id': '5750b013498e755287c6de97',
#     'name': 'Some Time BBQ Grill Restaurant 碳烤屋',
#     'location': {'address': '988 Baldwin Street',
#      'lat': 43.655874,
#      'lng': -79.393826,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.655874,
#        'lng': -79.393826}],
#      'distance': 1799,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['988 Baldwin Street', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '52af3b773cf9994f4e043c03',
#       'name': 'Szechuan Restaurant',
#       'pluralName': 'Szechuan Restaurants',
#       'shortName': 'Szechuan',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588352904',
#     'hasPerk': False},
#    {'id': '4ead8aa602d5cf33fa765b07',
#     'name': 'Restaurant at Number One',
#     'location': {'address': '77/99 Harbour Sq.',
#      'crossStreet': 'York & Queens Quay',
#      'lat': 43.639044,
#      'lng': -79.377653,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.639044,
#        'lng': -79.377653}],
#      'distance': 642,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['77/99 Harbour Sq. (York & Queens Quay)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588352904',
#     'hasPerk': False},
#    {'id': '4bce1ec0cc8cd13a9ac8c3cf',
#     'name': 'Kensington Cornerstone Restaurant',
#     'location': {'address': '2A Kensington Ave.',
#      'crossStreet': 'Dundas St. W',
#      'lat': 43.65280330843737,
#      'lng': -79.39995806711424,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65280330843737,
#        'lng': -79.39995806711424}],
#      'distance': 1776,
#      'postalCode': 'M5T 2J7',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['2A Kensington Ave. (Dundas St. W)',
#       'Toronto ON M5T 2J7',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d143941735',
#       'name': 'Breakfast Spot',
#       'pluralName': 'Breakfast Spots',
#       'shortName': 'Breakfast',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588352904',
#     'hasPerk': False},
#    {'id': '4d06c1ccc2e53704428cc567',
#     'name': 'North-East Chinese Restaurant 華北美食',
#     'location': {'address': '476 Dundas St.',
#      'crossStreet': 'Huron',
#      'lat': 43.6531846832903,
#      'lng': -79.3966766276528,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6531846832903,
#        'lng': -79.3966766276528}],
#      'distance': 1645,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['476 Dundas St. (Huron)', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588352904',
#     'hasPerk': False},
#    {'id': '4ba2d00cf964a5203e1b38e3',
#     'name': 'Ka Chi Korean Restaurant',
#     'location': {'address': '8 St Andrew St.',
#      'crossStreet': 'at Spadina Ave.',
#      'lat': 43.654306552286656,
#      'lng': -79.3992765578534,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.654306552286656,
#        'lng': -79.3992765578534}],
#      'distance': 1869,
#      'postalCode': 'M5T 1K6',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['8 St Andrew St. (at Spadina Ave.)',
#       'Toronto ON M5T 1K6',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d113941735',
#       'name': 'Korean Restaurant',
#       'pluralName': 'Korean Restaurants',
#       'shortName': 'Korean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588352904',
#     'hasPerk': False},
#    {'id': '4ae29812f964a520288f21e3',
#     'name': 'Swatow Restaurant 汕頭小食家',
#     'location': {'address': '309 Spadina Ave.',
#      'crossStreet': "btwn Dundas St. W & D'Arcy St.",
#      'lat': 43.65386562507761,
#      'lng': -79.39833353339202,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65386562507761,
#        'lng': -79.39833353339202}],
#      'distance': 1784,
#      'postalCode': 'M5T 2E6',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ["309 Spadina Ave. (btwn Dundas St. W & D'Arcy St.)",
#       'Toronto ON M5T 2E6',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588352904',
#     'hasPerk': False},
#    {'id': '4e78cc8dfa769112d58372f0',
#     'name': 'Edo Restaurant',
#     'location': {'address': 'Metro Convention Centre',
#      'lat': 43.642706,
#      'lng': -79.385405,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.642706,
#        'lng': -79.385405}],
#      'distance': 194,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Metro Convention Centre', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588352904',
#     'hasPerk': False},
#    {'id': '4b074bb1f964a52077fb22e3',
#     'name': 'New Sky Restaurant 小沙田食家',
#     'location': {'address': '353 Spadina Ave.',
#      'lat': 43.65533674412141,
#      'lng': -79.39889716243826,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65533674412141,
#        'lng': -79.39889716243826}],
#      'distance': 1944,
#      'postalCode': 'M5T 2G3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['353 Spadina Ave.', 'Toronto ON M5T 2G3', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588352904',
#     'hasPerk': False},
#    {'id': '5a7c3e079de23b294a2c4117',
#     'name': 'Restaurant | Adelaide',
#     'location': {'address': '325 Bay St (31st floor)',
#      'lat': 43.649563,
#      'lng': -79.38059,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.649563,
#        'lng': -79.38059}],
#      'distance': 1025,
#      'postalCode': 'M5H',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['325 Bay St (31st floor)',
#       'Toronto ON M5H',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588352904',
#     'hasPerk': False},
#    {'id': '5b1c3098f96b2c002c5eb0c5',
#     'name': "Tasty's Caribbean Restaurant & Catering",
#     'location': {'address': '405 Spadina Ave',
#      'crossStreet': 'College St',
#      'lat': 43.656794,
#      'lng': -79.399251,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.656794,
#        'lng': -79.399251}],
#      'distance': 2095,
#      'postalCode': 'M5T 2G6',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['405 Spadina Ave (College St)',
#       'Toronto ON M5T 2G6',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d144941735',
#       'name': 'Caribbean Restaurant',
#       'pluralName': 'Caribbean Restaurants',
#       'shortName': 'Caribbean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/caribbean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588352904',
#     'hasPerk': False},
#    {'id': '4cdc95d6d549548162a042b2',
#     'name': 'Ten Restaurant & Wine Bar, Port credit',
#     'location': {'lat': 43.63963228023868,
#      'lng': -79.38805057479127,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.63963228023868,
#        'lng': -79.38805057479127}],
#      'distance': 275,
#      'cc': 'CA',
#      'city': 'Mississauga',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Mississauga ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588352904',
#     'hasPerk': False},
#    {'id': '4b7aed4af964a52095462fe3',
#     'name': 'Ito Sushi & Noodle Restaurant',
#     'location': {'address': '250 Front St W',
#      'lat': 43.644808971551775,
#      'lng': -79.38769621528486,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.644808971551775,
#        'lng': -79.38769621528486}],
#      'distance': 473,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['250 Front St W', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588352904',
#     'hasPerk': False},
#    {'id': '4ae094a7f964a5208f8021e3',
#     'name': 'SCHOOL Restaurant',
#     'location': {'address': '70 Fraser Ave.',
#      'crossStreet': 'at Liberty St.',
#      'lat': 43.6377753703417,
#      'lng': -79.42429737067897,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6377753703417,
#        'lng': -79.42429737067897}],
#      'distance': 3172,
#      'postalCode': 'M6K 3C5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['70 Fraser Ave. (at Liberty St.)',
#       'Toronto ON M6K 3C5',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d143941735',
#       'name': 'Breakfast Spot',
#       'pluralName': 'Breakfast Spots',
#       'shortName': 'Breakfast',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '38118429'},
#     'referralId': 'v-1588352904',
#     'hasPerk': False},
#    {'id': '4e81ac628b81fd59e7baddf9',
#     'name': 'Windows Restaurant',
#     'location': {'address': 'Rogers Centre',
#      'lat': 43.641535,
#      'lng': -79.389271,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.641535,
#        'lng': -79.389271}],
#      'distance': 336,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Rogers Centre', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588352904',
#     'hasPerk': False},
#    {'id': '4afa1f33f964a520e91622e3',
#     'name': 'Fune Japanese Restaurant',
#     'location': {'address': '100 Simcoe St.',
#      'crossStreet': 'at Pearl St.',
#      'lat': 43.64851365544565,
#      'lng': -79.38645657820041,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64851365544565,
#        'lng': -79.38645657820041}],
#      'distance': 846,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['100 Simcoe St. (at Pearl St.)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588352904',
#     'hasPerk': False},
#    {'id': '4bd47e6fcfa7b7139f2924da',
#     'name': 'Studio Restaurant',
#     'location': {'address': '389 Church St.',
#      'crossStreet': 'at Carlton St.',
#      'lat': 43.661500159065305,
#      'lng': -79.3793192447337,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.661500159065305,
#        'lng': -79.3793192447337}],
#      'distance': 2333,
#      'postalCode': 'M5B',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['389 Church St. (at Carlton St.)',
#       'Toronto ON M5B',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d143941735',
#       'name': 'Breakfast Spot',
#       'pluralName': 'Breakfast Spots',
#       'shortName': 'Breakfast',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588352904',
#     'hasPerk': False},
#    {'id': '4ad4c05ff964a52018f720e3',
#     'name': 'Cottage Restaurant & Lounge',
#     'location': {'address': '338 Jarvis St.',
#      'crossStreet': 'north of Carlton Street',
#      'lat': 43.66277006654972,
#      'lng': -79.37689434011018,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.66277006654972,
#        'lng': -79.37689434011018}],
#      'distance': 2516,
#      'postalCode': 'M4Y 2G6',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['338 Jarvis St. (north of Carlton Street)',
#       'Toronto ON M4Y 2G6',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588352904',
#     'hasPerk': False},
#    {'id': '4b22e814f964a520175024e3',
#     'name': 'The Lakeview Restaurant',
#     'location': {'address': '1132 Dundas St. W',
#      'crossStreet': 'at Ossington Ave.',
#      'lat': 43.64943515996231,
#      'lng': -79.42039021958406,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64943515996231,
#        'lng': -79.42039021958406}],
#      'distance': 2989,
#      'postalCode': 'M6J 1X2',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['1132 Dundas St. W (at Ossington Ave.)',
#       'Toronto ON M6J 1X2',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d147941735',
#       'name': 'Diner',
#       'pluralName': 'Diners',
#       'shortName': 'Diner',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588352904',
#     'hasPerk': False},
#    {'id': '4ad4c05cf964a520e1f520e3',
#     'name': 'Docks Restaurant & Night Club The',
#     'location': {'address': '11 Polson St.',
#      'crossStreet': 'at Cherry',
#      'lat': 43.641805689100366,
#      'lng': -79.35417083642646,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.641805689100366,
#        'lng': -79.35417083642646}],
#      'distance': 2499,
#      'postalCode': 'M5A 1A4',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['11 Polson St. (at Cherry)',
#       'Toronto ON M5A 1A4',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588352904',
#     'hasPerk': False},
#    {'id': '537e313d498e9e9e015f3018',
#     'name': 'Montecito Restaurant',
#     'location': {'address': '299 Adelaide St W',
#      'crossStreet': 'Peter St',
#      'lat': 43.64764401408166,
#      'lng': -79.3910688649793,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64764401408166,
#        'lng': -79.3910688649793}],
#      'distance': 882,
#      'postalCode': 'M5V 1P7',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['299 Adelaide St W (Peter St)',
#       'Toronto ON M5V 1P7',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '145052232'},
#     'referralId': 'v-1588352904',
#     'hasPerk': False},
#    {'id': '4ad4c060f964a52074f720e3',
#     'name': 'Penelope Restaurant',
#     'location': {'address': '225 King St. W',
#      'lat': 43.64663716228099,
#      'lng': -79.38856799565981,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64663716228099,
#        'lng': -79.38856799565981}],
#      'distance': 688,
#      'postalCode': 'M5V 3C5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['225 King St. W', 'Toronto ON M5V 3C5', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d10e941735',
#       'name': 'Greek Restaurant',
#       'pluralName': 'Greek Restaurants',
#       'shortName': 'Greek',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/greek_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588352904',
#     'hasPerk': False},
#    {'id': '4ad4c05df964a52027f620e3',
#     'name': 'Lusso Restaurant and Bar',
#     'location': {'address': "207 Queen's Quay West",
#      'lat': 43.63809395443668,
#      'lng': -79.38066560097575,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.63809395443668,
#        'lng': -79.38066560097575}],
#      'distance': 483,
#      'postalCode': 'M5J 1A7',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ["207 Queen's Quay West",
#       'Toronto ON M5J 1A7',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d121941735',
#       'name': 'Lounge',
#       'pluralName': 'Lounges',
#       'shortName': 'Lounge',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588352904',
#     'hasPerk': False},
#    {'id': '4af23cabf964a520d4e621e3',
#     'name': 'Pizza Rustica Restaurant & Bar',
#     'location': {'address': '37 Blue Jays Way',
#      'lat': 43.64491920354413,
#      'lng': -79.3918436177755,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64491920354413,
#        'lng': -79.3918436177755}],
#      'distance': 694,
#      'postalCode': 'M5V 3P5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['37 Blue Jays Way', 'Toronto ON M5V 3P5', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588352904',
#     'hasPerk': False},
#    {'id': '55413a52498e17074d38e6f5',
#     'name': 'ResoSolutions - Online Restaurant Booking System & Software',
#     'location': {'address': '1 Yonge Street',
#      'crossStreet': 'Suite 1801',
#      'lat': 43.642566229238305,
#      'lng': -79.37525510787964,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.642566229238305,
#        'lng': -79.37525510787964}],
#      'distance': 818,
#      'postalCode': 'M5E 1W7',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['1 Yonge Street (Suite 1801)',
#       'Toronto ON M5E 1W7',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588352904',
#     'hasPerk': False},
#    {'id': '5818949e38faf9fd729f900c',
#     'name': 'Lao Thai Restaurant',
#     'location': {'address': '4 Gladstone Ave',
#      'crossStreet': 'Queen street West',
#      'lat': 43.64284875,
#      'lng': -79.42754375000001,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64284875,
#        'lng': -79.42754375000001}],
#      'distance': 3419,
#      'postalCode': 'M6J 3K6',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['4 Gladstone Ave (Queen street West)',
#       'Toronto ON M6J 3K6',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588352904',
#     'hasPerk': False},
#    {'id': '4ad8a5a7f964a5203c1321e3',
#     'name': 'Little India Restaurant',
#     'location': {'address': '255 Queen St. W',
#      'crossStreet': 'Queen and University',
#      'lat': 43.65031880877208,
#      'lng': -79.38899760320798,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65031880877208,
#        'lng': -79.38899760320798}],
#      'distance': 1085,
#      'postalCode': 'M5V 1Z4',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['255 Queen St. W (Queen and University)',
#       'Toronto ON M5V 1Z4',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '57793907'},
#     'referralId': 'v-1588352904',
#     'hasPerk': False},
#    {'id': '4d542fc4f9f9b60c3b8d2be6',
#     'name': 'Bottom Line Restaurant & Bar',
#     'location': {'address': '22 Front St W',
#      'lat': 43.646286,
#      'lng': -79.378086,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.646286,
#        'lng': -79.378086}],
#      'distance': 822,
#      'postalCode': 'M5J 2T3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['22 Front St W', 'Toronto ON M5J 2T3', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '35051000'},
#     'referralId': 'v-1588352904',
#     'hasPerk': False},
#    {'id': '4c31214866e40f471b99c48b',
#     'name': 'Excellent Chinese Restaurant',
#     'location': {'lat': 43.639239810318365,
#      'lng': -79.39227848580624,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.639239810318365,
#        'lng': -79.39227848580624}],
#      'distance': 604,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588352904',
#     'hasPerk': False},
#    {'id': '5b54d8944420d8002c9a2e3b',
#     'name': 'Siempre Restaurant',
#     'location': {'address': '348 Front St. W.',
#      'lat': 43.643127,
#      'lng': -79.392296,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.643127,
#        'lng': -79.392296}],
#      'distance': 622,
#      'postalCode': 'M5V 3S8',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['348 Front St. W.', 'Toronto ON M5V 3S8', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d143941735',
#       'name': 'Breakfast Spot',
#       'pluralName': 'Breakfast Spots',
#       'shortName': 'Breakfast',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588352904',
#     'hasPerk': False},
#    {'id': '4b4d3b51f964a520e4ce26e3',
#     'name': 'Matisse Restaurant And Bar',
#     'location': {'address': '90 Bloor St.',
#      'crossStreet': 'Yonge St.',
#      'lat': 43.67057375344845,
#      'lng': -79.38485582052517,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.67057375344845,
#        'lng': -79.38485582052517}],
#      'distance': 3295,
#      'postalCode': 'M4W 1A7',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['90 Bloor St. (Yonge St.)',
#       'Toronto ON M4W 1A7',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '83923512'},
#     'referralId': 'v-1588352904',
#     'hasPerk': False},
#    {'id': '4ad4c05cf964a520cef520e3',
#     'name': 'Sassafraz | Cafe | Restaurant | Private Events',
#     'location': {'address': '100 Cumberland Street',
#      'crossStreet': 'Bellair St',
#      'lat': 43.67034226367314,
#      'lng': -79.39104050451753,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.67034226367314,
#        'lng': -79.39104050451753}],
#      'distance': 3304,
#      'postalCode': 'M5R 1A6',
#      'cc': 'CA',
#      'neighborhood': 'Yorkville',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['100 Cumberland Street (Bellair St)',
#       'Toronto ON M5R 1A6',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d171941735',
#       'name': 'Event Space',
#       'pluralName': 'Event Spaces',
#       'shortName': 'Event Space',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/eventspace_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588352904',
#     'hasPerk': False},
#    {'id': '5b74375433e118002cf5d511',
#     'name': 'Flexday At Victor Restaurant',
#     'location': {'address': '30 Mercer St',
#      'lat': 43.645652,
#      'lng': -79.391123,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.645652,
#        'lng': -79.391123}],
#      'distance': 708,
#      'postalCode': 'M5V 1H3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['30 Mercer St', 'Toronto ON M5V 1H3', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d174941735',
#       'name': 'Coworking Space',
#       'pluralName': 'Coworking Spaces',
#       'shortName': 'Coworking Space',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/office_coworkingspace_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588352904',
#     'hasPerk': False},
#    {'id': '4ada6d8df964a520832221e3',
#     'name': 'Union Restaurant',
#     'location': {'address': '72 Ossington Ave.',
#      'crossStreet': 'Queen St. W',
#      'lat': 43.64585979013257,
#      'lng': -79.41953208988866,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64585979013257,
#        'lng': -79.41953208988866}],
#      'distance': 2821,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['72 Ossington Ave. (Queen St. W)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d157941735',
#       'name': 'New American Restaurant',
#       'pluralName': 'New American Restaurants',
#       'shortName': 'New American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/newamerican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588352904',
#     'hasPerk': False},
#    {'id': '4ceabf5f0f196dcb93b253ae',
#     'name': 'Quiznos Canada Restaurant Corporation',
#     'location': {'address': '355 king street west',
#      'lat': 43.645459,
#      'lng': -79.391797,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.645459,
#        'lng': -79.391797}],
#      'distance': 731,
#      'postalCode': 'M5V 1J6',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['355 king street west',
#       'Toronto ON M5V 1J6',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d174941735',
#       'name': 'Coworking Space',
#       'pluralName': 'Coworking Spaces',
#       'shortName': 'Coworking Space',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/office_coworkingspace_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588352904',
#     'hasPerk': False}]}}

# %% [markdown]
# #### Assign venue data to a panda dataframe

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
df = json_normalize(venues)
df
# Out:
#                                            categories  hasPerk  \
# 0   [{'id': '4bf58dd8d48988d123941735', 'name': 'W...    False
# 1   [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...    False
# 2   [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...    False
# 3   [{'id': '4bf58dd8d48988d14e941735', 'name': 'A...    False
# 4   [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...    False
# 5   [{'id': '4bf58dd8d48988d116941735', 'name': 'B...    False
# 6   [{'id': '4bf58dd8d48988d14e941735', 'name': 'A...    False
# 7   [{'id': '4bf58dd8d48988d1f5931735', 'name': 'D...    False
# 8   [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...    False
# 9   [{'id': '4bf58dd8d48988d14e941735', 'name': 'A...    False
# 10  [{'id': '4bf58dd8d48988d1d1941735', 'name': 'N...    False
# 11  [{'id': '4bf58dd8d48988d146941735', 'name': 'D...    False
# 12  [{'id': '4bf58dd8d48988d1f5931735', 'name': 'D...    False
# 13  [{'id': '4bf58dd8d48988d116941735', 'name': 'B...    False
# 14  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...    False
# 15  [{'id': '4bf58dd8d48988d1d2941735', 'name': 'S...    False
# 16  [{'id': '52af3b773cf9994f4e043c03', 'name': 'S...    False
# 17  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...    False
# 18  [{'id': '4bf58dd8d48988d143941735', 'name': 'B...    False
# 19  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...    False
# 20  [{'id': '4bf58dd8d48988d113941735', 'name': 'K...    False
# 21  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...    False
# 22  [{'id': '4bf58dd8d48988d142941735', 'name': 'A...    False
# 23  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...    False
# 24  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...    False
# 25  [{'id': '4bf58dd8d48988d144941735', 'name': 'C...    False
# 26  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...    False
# 27  [{'id': '4bf58dd8d48988d111941735', 'name': 'J...    False
# 28  [{'id': '4bf58dd8d48988d143941735', 'name': 'B...    False
# 29  [{'id': '4d4b7105d754a06374d81259', 'name': 'F...    False
# 30  [{'id': '4bf58dd8d48988d111941735', 'name': 'J...    False
# 31  [{'id': '4bf58dd8d48988d143941735', 'name': 'B...    False
# 32  [{'id': '4bf58dd8d48988d149941735', 'name': 'T...    False
# 33  [{'id': '4bf58dd8d48988d147941735', 'name': 'D...    False
# 34  [{'id': '4bf58dd8d48988d116941735', 'name': 'B...    False
# 35  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...    False
# 36  [{'id': '4bf58dd8d48988d10e941735', 'name': 'G...    False
# 37  [{'id': '4bf58dd8d48988d121941735', 'name': 'L...    False
# 38  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...    False
# 39  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...    False
# 40  [{'id': '4bf58dd8d48988d149941735', 'name': 'T...    False
# 41  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...    False
# 42  [{'id': '4bf58dd8d48988d116941735', 'name': 'B...    False
# 43  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...    False
# 44  [{'id': '4bf58dd8d48988d143941735', 'name': 'B...    False
# 45  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...    False
# 46  [{'id': '4bf58dd8d48988d171941735', 'name': 'E...    False
# 47  [{'id': '4bf58dd8d48988d174941735', 'name': 'C...    False
# 48  [{'id': '4bf58dd8d48988d157941735', 'name': 'N...    False
# 49  [{'id': '4bf58dd8d48988d174941735', 'name': 'C...    False
#
#                           id                 location.address location.cc  \
# 0   4ad4c05cf964a520dff520e3                   301 Front St W          CA
# 1   4ad4c060f964a5208af720e3                  1 Blue Jays Way          CA
# 2   4aef8854f964a5201cd921e3                   287 King St. W          CA
# 3   4bc3ad5e461576b0db037f32                    Rogers Centre          CA
# 4   4b223f5af964a520ba4424e3                   225 Front St W          CA
# 5   4ad4c05df964a5203ff620e3                 30 Mercer Street          CA
# 6   4ada5d5bf964a520e92121e3                     35 Church St          CA
# 7   4b072e9df964a52009f922e3                 280 Spadina Ave.          CA
# 8   4ad4c05cf964a52006f620e3              37 King Street East          CA
# 9   4ad4c05ff964a52048f720e3              110 Chestnut Street          CA
# 10  4b266f05f964a520657b24e3                  266 Spadina Ave          CA
# 11  562922be498e2c6aad0e6091               25 Lower Simcoe St          CA
# 12  4ad4c060f964a5207ff720e3                 323 Spadina Ave.          CA
# 13  4c47d78c1ddec92817ca9e32                   566 Queen St W          CA
# 14  5c33c7cd8194fc002c66f72e  261 Spadina Avenue. Upper level          CA
# 15  501d4d55e4b0825080212f3c                262 Queens Quay W          CA
# 16  5750b013498e755287c6de97               988 Baldwin Street          CA
# 17  4ead8aa602d5cf33fa765b07                77/99 Harbour Sq.          CA
# 18  4bce1ec0cc8cd13a9ac8c3cf               2A Kensington Ave.          CA
# 19  4d06c1ccc2e53704428cc567                   476 Dundas St.          CA
# 20  4ba2d00cf964a5203e1b38e3                  8 St Andrew St.          CA
# 21  4ae29812f964a520288f21e3                 309 Spadina Ave.          CA
# 22  4e78cc8dfa769112d58372f0          Metro Convention Centre          CA
# 23  4b074bb1f964a52077fb22e3                 353 Spadina Ave.          CA
# 24  5a7c3e079de23b294a2c4117          325 Bay St (31st floor)          CA
# 25  5b1c3098f96b2c002c5eb0c5                  405 Spadina Ave          CA
# 26  4cdc95d6d549548162a042b2                              NaN          CA
# 27  4b7aed4af964a52095462fe3                   250 Front St W          CA
# 28  4ae094a7f964a5208f8021e3                   70 Fraser Ave.          CA
# 29  4e81ac628b81fd59e7baddf9                    Rogers Centre          CA
# 30  4afa1f33f964a520e91622e3                   100 Simcoe St.          CA
# 31  4bd47e6fcfa7b7139f2924da                   389 Church St.          CA
# 32  4ad4c05ff964a52018f720e3                   338 Jarvis St.          CA
# 33  4b22e814f964a520175024e3                1132 Dundas St. W          CA
# 34  4ad4c05cf964a520e1f520e3                    11 Polson St.          CA
# 35  537e313d498e9e9e015f3018                299 Adelaide St W          CA
# 36  4ad4c060f964a52074f720e3                   225 King St. W          CA
# 37  4ad4c05df964a52027f620e3            207 Queen's Quay West          CA
# 38  4af23cabf964a520d4e621e3                 37 Blue Jays Way          CA
# 39  55413a52498e17074d38e6f5                   1 Yonge Street          CA
# 40  5818949e38faf9fd729f900c                  4 Gladstone Ave          CA
# 41  4ad8a5a7f964a5203c1321e3                  255 Queen St. W          CA
# 42  4d542fc4f9f9b60c3b8d2be6                    22 Front St W          CA
# 43  4c31214866e40f471b99c48b                              NaN          CA
# 44  5b54d8944420d8002c9a2e3b                 348 Front St. W.          CA
# 45  4b4d3b51f964a520e4ce26e3                     90 Bloor St.          CA
# 46  4ad4c05cf964a520cef520e3            100 Cumberland Street          CA
# 47  5b74375433e118002cf5d511                     30 Mercer St          CA
# 48  4ada6d8df964a520832221e3                72 Ossington Ave.          CA
# 49  4ceabf5f0f196dcb93b253ae             355 king street west          CA
#
#    location.city location.country                location.crossStreet  \
# 0        Toronto           Canada                     301 Front St. W
# 1        Toronto           Canada        inside the Renaissance Hotel
# 2        Toronto           Canada                         at John St.
# 3        Toronto           Canada                                 NaN
# 4        Toronto           Canada  in InterContinental Toronto Centre
# 5        Toronto           Canada                          at John St
# 6        Toronto           Canada                       at Front St E
# 7        Toronto           Canada                    at Dundas St. W.
# 8        Toronto           Canada    at Le Meridien King Edward Hotel
# 9        Toronto           Canada                                 NaN
# 10       Toronto           Canada                      at Willison Sq
# 11       Toronto           Canada                   Grand Trunk Cresc
# 12       Toronto           Canada                       at D'Arcy St.
# 13       Toronto           Canada                                 NaN
# 14       Toronto           Canada                                 NaN
# 15       Toronto           Canada                                 NaN
# 16       Toronto           Canada                                 NaN
# 17       Toronto           Canada                  York & Queens Quay
# 18       Toronto           Canada                        Dundas St. W
# 19       Toronto           Canada                               Huron
# 20       Toronto           Canada                     at Spadina Ave.
# 21       Toronto           Canada      btwn Dundas St. W & D'Arcy St.
# 22       Toronto           Canada                                 NaN
# 23       Toronto           Canada                                 NaN
# 24       Toronto           Canada                                 NaN
# 25       Toronto           Canada                          College St
# 26   Mississauga           Canada                                 NaN
# 27       Toronto           Canada                                 NaN
# 28       Toronto           Canada                      at Liberty St.
# 29       Toronto           Canada                                 NaN
# 30       Toronto           Canada                        at Pearl St.
# 31       Toronto           Canada                      at Carlton St.
# 32       Toronto           Canada             north of Carlton Street
# 33       Toronto           Canada                   at Ossington Ave.
# 34       Toronto           Canada                           at Cherry
# 35       Toronto           Canada                            Peter St
# 36       Toronto           Canada                                 NaN
# 37       Toronto           Canada                                 NaN
# 38       Toronto           Canada                                 NaN
# 39       Toronto           Canada                          Suite 1801
# 40       Toronto           Canada                   Queen street West
# 41       Toronto           Canada                Queen and University
# 42       Toronto           Canada                                 NaN
# 43       Toronto           Canada                                 NaN
# 44       Toronto           Canada                                 NaN
# 45       Toronto           Canada                           Yonge St.
# 46       Toronto           Canada                          Bellair St
# 47       Toronto           Canada                                 NaN
# 48       Toronto           Canada                         Queen St. W
# 49       Toronto           Canada                                 NaN
#
#     location.distance                          location.formattedAddress  \
# 0                 230  [301 Front St W (301 Front St. W), Toronto ON ...
# 1                 319  [1 Blue Jays Way (inside the Renaissance Hotel...
# 2                 710  [287 King St. W (at John St.), Toronto ON M5V ...
# 3                 345                [Rogers Centre, Toronto ON, Canada]
# 4                 421  [225 Front St W (in InterContinental Toronto C...
# 5                 707  [30 Mercer Street (at John St), Toronto ON M5V...
# 6                1272  [35 Church St (at Front St E), Toronto ON M5E ...
# 7                1681  [280 Spadina Ave. (at Dundas St. W.), Toronto ...
# 8                1164  [37 King Street East (at Le Meridien King Edwa...
# 9                1550  [110 Chestnut Street, Toronto ON M5G 1R3, Canada]
# 10               1630  [266 Spadina Ave (at Willison Sq), Toronto ON ...
# 11                154  [25 Lower Simcoe St (Grand Trunk Cresc), Toron...
# 12               1840  [323 Spadina Ave. (at D'Arcy St.), Toronto ON ...
# 13               1635               [566 Queen St W, Toronto ON, Canada]
# 14               1622  [261 Spadina Avenue. Upper level, Toronto ON M...
# 15                225            [262 Queens Quay W, Toronto ON, Canada]
# 16               1799           [988 Baldwin Street, Toronto ON, Canada]
# 17                642  [77/99 Harbour Sq. (York & Queens Quay), Toron...
# 18               1776  [2A Kensington Ave. (Dundas St. W), Toronto ON...
# 19               1645       [476 Dundas St. (Huron), Toronto ON, Canada]
# 20               1869  [8 St Andrew St. (at Spadina Ave.), Toronto ON...
# 21               1784  [309 Spadina Ave. (btwn Dundas St. W & D'Arcy ...
# 22                194      [Metro Convention Centre, Toronto ON, Canada]
# 23               1944     [353 Spadina Ave., Toronto ON M5T 2G3, Canada]
# 24               1025  [325 Bay St (31st floor), Toronto ON M5H, Canada]
# 25               2095  [405 Spadina Ave (College St), Toronto ON M5T ...
# 26                275                           [Mississauga ON, Canada]
# 27                473               [250 Front St W, Toronto ON, Canada]
# 28               3172  [70 Fraser Ave. (at Liberty St.), Toronto ON M...
# 29                336                [Rogers Centre, Toronto ON, Canada]
# 30                846  [100 Simcoe St. (at Pearl St.), Toronto ON, Ca...
# 31               2333  [389 Church St. (at Carlton St.), Toronto ON M...
# 32               2516  [338 Jarvis St. (north of Carlton Street), Tor...
# 33               2989  [1132 Dundas St. W (at Ossington Ave.), Toront...
# 34               2499  [11 Polson St. (at Cherry), Toronto ON M5A 1A4...
# 35                882  [299 Adelaide St W (Peter St), Toronto ON M5V ...
# 36                688       [225 King St. W, Toronto ON M5V 3C5, Canada]
# 37                483  [207 Queen's Quay West, Toronto ON M5J 1A7, Ca...
# 38                694     [37 Blue Jays Way, Toronto ON M5V 3P5, Canada]
# 39                818  [1 Yonge Street (Suite 1801), Toronto ON M5E 1...
# 40               3419  [4 Gladstone Ave (Queen street West), Toronto ...
# 41               1085  [255 Queen St. W (Queen and University), Toron...
# 42                822        [22 Front St W, Toronto ON M5J 2T3, Canada]
# 43                604                               [Toronto ON, Canada]
# 44                622     [348 Front St. W., Toronto ON M5V 3S8, Canada]
# 45               3295  [90 Bloor St. (Yonge St.), Toronto ON M4W 1A7,...
# 46               3304  [100 Cumberland Street (Bellair St), Toronto O...
# 47                708         [30 Mercer St, Toronto ON M5V 1H3, Canada]
# 48               2821  [72 Ossington Ave. (Queen St. W), Toronto ON, ...
# 49                731  [355 king street west, Toronto ON M5V 1J6, Can...
#
#                               location.labeledLatLngs  location.lat  \
# 0   [{'label': 'display', 'lat': 43.64253731714456...     43.642537
# 1   [{'label': 'display', 'lat': 43.64147925628281...     43.641479
# 2   [{'label': 'display', 'lat': 43.64646252150344...     43.646463
# 3   [{'label': 'display', 'lat': 43.64163507221119...     43.641635
# 4   [{'label': 'display', 'lat': 43.64474919591934...     43.644749
# 5   [{'label': 'display', 'lat': 43.64563436248102...     43.645634
# 6   [{'label': 'display', 'lat': 43.64882370529773...     43.648824
# 7   [{'label': 'display', 'lat': 43.65278331265585...     43.652783
# 8   [{'label': 'display', 'lat': 43.64929834396347...     43.649298
# 9   [{'label': 'display', 'lat': 43.65488413420439...     43.654884
# 10  [{'label': 'display', 'lat': 43.6522783893466,...     43.652278
# 11  [{'label': 'display', 'lat': 43.64157991761808...     43.641580
# 12  [{'label': 'display', 'lat': 43.65431754076345...     43.654318
# 13  [{'label': 'display', 'lat': 43.64728932229506...     43.647289
# 14  [{'label': 'display', 'lat': 43.65248783033554...     43.652488
# 15  [{'label': 'display', 'lat': 43.63901430970685...     43.639014
# 16  [{'label': 'display', 'lat': 43.655874, 'lng':...     43.655874
# 17  [{'label': 'display', 'lat': 43.639044, 'lng':...     43.639044
# 18  [{'label': 'display', 'lat': 43.65280330843737...     43.652803
# 19  [{'label': 'display', 'lat': 43.6531846832903,...     43.653185
# 20  [{'label': 'display', 'lat': 43.65430655228665...     43.654307
# 21  [{'label': 'display', 'lat': 43.65386562507761...     43.653866
# 22  [{'label': 'display', 'lat': 43.642706, 'lng':...     43.642706
# 23  [{'label': 'display', 'lat': 43.65533674412141...     43.655337
# 24  [{'label': 'display', 'lat': 43.649563, 'lng':...     43.649563
# 25  [{'label': 'display', 'lat': 43.656794, 'lng':...     43.656794
# 26  [{'label': 'display', 'lat': 43.63963228023868...     43.639632
# 27  [{'label': 'display', 'lat': 43.64480897155177...     43.644809
# 28  [{'label': 'display', 'lat': 43.6377753703417,...     43.637775
# 29  [{'label': 'display', 'lat': 43.641535, 'lng':...     43.641535
# 30  [{'label': 'display', 'lat': 43.64851365544565...     43.648514
# 31  [{'label': 'display', 'lat': 43.66150015906530...     43.661500
# 32  [{'label': 'display', 'lat': 43.66277006654972...     43.662770
# 33  [{'label': 'display', 'lat': 43.64943515996231...     43.649435
# 34  [{'label': 'display', 'lat': 43.64180568910036...     43.641806
# 35  [{'label': 'display', 'lat': 43.64764401408166...     43.647644
# 36  [{'label': 'display', 'lat': 43.64663716228099...     43.646637
# 37  [{'label': 'display', 'lat': 43.63809395443668...     43.638094
# 38  [{'label': 'display', 'lat': 43.64491920354413...     43.644919
# 39  [{'label': 'display', 'lat': 43.64256622923830...     43.642566
# 40  [{'label': 'display', 'lat': 43.64284875, 'lng...     43.642849
# 41  [{'label': 'display', 'lat': 43.65031880877208...     43.650319
# 42  [{'label': 'display', 'lat': 43.646286, 'lng':...     43.646286
# 43  [{'label': 'display', 'lat': 43.63923981031836...     43.639240
# 44  [{'label': 'display', 'lat': 43.643127, 'lng':...     43.643127
# 45  [{'label': 'display', 'lat': 43.67057375344845...     43.670574
# 46  [{'label': 'display', 'lat': 43.67034226367314...     43.670342
# 47  [{'label': 'display', 'lat': 43.645652, 'lng':...     43.645652
# 48  [{'label': 'display', 'lat': 43.64585979013257...     43.645860
# 49  [{'label': 'display', 'lat': 43.645459, 'lng':...     43.645459
#
#     location.lng   location.neighborhood location.postalCode location.state  \
# 0     -79.387042                     NaN             M5V 2T6             ON
# 1     -79.389074                     NaN             M5V 1J4             ON
# 2     -79.389644                     NaN             M5V 1J5             ON
# 3     -79.389365                     NaN                 NaN             ON
# 4     -79.385113  Entertainment District             M5V 2X3             ON
# 5     -79.391125                     NaN             M5V 1H3             ON
# 6     -79.373702                     NaN             M5E 1T3             ON
# 7     -79.398174                     NaN                 NaN             ON
# 8     -79.376431                     NaN             M5C 1E9             ON
# 9     -79.385931                     NaN             M5G 1R3             ON
# 10    -79.398039                     NaN             M5T 2E4             ON
# 11    -79.383456                     NaN             M5J 3A1             ON
# 12    -79.398650       Kensington Market             M5T 2E9             ON
# 13    -79.403493                     NaN                 NaN             ON
# 14    -79.397501                     NaN             M5T 2E3             ON
# 15    -79.385914                     NaN                 NaN             ON
# 16    -79.393826                     NaN                 NaN             ON
# 17    -79.377653                     NaN                 NaN             ON
# 18    -79.399958                     NaN             M5T 2J7             ON
# 19    -79.396677                     NaN                 NaN             ON
# 20    -79.399277                     NaN             M5T 1K6             ON
# 21    -79.398334                     NaN             M5T 2E6             ON
# 22    -79.385405                     NaN                 NaN             ON
# 23    -79.398897                     NaN             M5T 2G3             ON
# 24    -79.380590                     NaN                 M5H             ON
# 25    -79.399251                     NaN             M5T 2G6             ON
# 26    -79.388051                     NaN                 NaN             ON
# 27    -79.387696                     NaN                 NaN             ON
# 28    -79.424297                     NaN             M6K 3C5             ON
# 29    -79.389271                     NaN                 NaN             ON
# 30    -79.386457                     NaN                 NaN             ON
# 31    -79.379319                     NaN                 M5B             ON
# 32    -79.376894                     NaN             M4Y 2G6             ON
# 33    -79.420390                     NaN             M6J 1X2             ON
# 34    -79.354171                     NaN             M5A 1A4             ON
# 35    -79.391069                     NaN             M5V 1P7             ON
# 36    -79.388568                     NaN             M5V 3C5             ON
# 37    -79.380666                     NaN             M5J 1A7             ON
# 38    -79.391844                     NaN             M5V 3P5             ON
# 39    -79.375255                     NaN             M5E 1W7             ON
# 40    -79.427544                     NaN             M6J 3K6             ON
# 41    -79.388998                     NaN             M5V 1Z4             ON
# 42    -79.378086                     NaN             M5J 2T3             ON
# 43    -79.392278                     NaN                 NaN             ON
# 44    -79.392296                     NaN             M5V 3S8             ON
# 45    -79.384856                     NaN             M4W 1A7             ON
# 46    -79.391041               Yorkville             M5R 1A6             ON
# 47    -79.391123                     NaN             M5V 1H3             ON
# 48    -79.419532                     NaN                 NaN             ON
# 49    -79.391797                     NaN             M5V 1J6             ON
#
#                                                  name    referralId  \
# 0                                      360 Restaurant  v-1588352904
# 1                                   Arriba Restaurant  v-1588352904
# 2                        Aroma Fine Indian Restaurant  v-1588352904
# 3                               Sightlines Restaurant  v-1588352904
# 4                              Azure Restaurant & Bar  v-1588352904
# 5                             Victor Restaurant & Bar  v-1588352904
# 6                      The Hot House Restaurant & Bar  v-1588352904
# 7                  Sky Dragon Chinese Restaurant 龍翔酒樓  v-1588352904
# 8                               Victoria's Restaurant  v-1588352904
# 9                     Hemispheres Restaurant & Bistro  v-1588352904
# 10                     Goldstone Noodle Restaurant 金石  v-1588352904
# 11                                  Evviva Restaurant  v-1588352904
# 12                             Rol San Restaurant 龍笙棧  v-1588352904
# 13                      Micheal's Restaurant and Deli  v-1588352904
# 14                      Green Tea Restaurant Downtown  v-1588352904
# 15                    Gonoe Sushi Japanese Restaurant  v-1588352904
# 16                 Some Time BBQ Grill Restaurant 碳烤屋  v-1588352904
# 17                           Restaurant at Number One  v-1588352904
# 18                  Kensington Cornerstone Restaurant  v-1588352904
# 19                 North-East Chinese Restaurant 華北美食  v-1588352904
# 20                           Ka Chi Korean Restaurant  v-1588352904
# 21                            Swatow Restaurant 汕頭小食家  v-1588352904
# 22                                     Edo Restaurant  v-1588352904
# 23                           New Sky Restaurant 小沙田食家  v-1588352904
# 24                              Restaurant | Adelaide  v-1588352904
# 25            Tasty's Caribbean Restaurant & Catering  v-1588352904
# 26             Ten Restaurant & Wine Bar, Port credit  v-1588352904
# 27                      Ito Sushi & Noodle Restaurant  v-1588352904
# 28                                  SCHOOL Restaurant  v-1588352904
# 29                                 Windows Restaurant  v-1588352904
# 30                           Fune Japanese Restaurant  v-1588352904
# 31                                  Studio Restaurant  v-1588352904
# 32                        Cottage Restaurant & Lounge  v-1588352904
# 33                            The Lakeview Restaurant  v-1588352904
# 34                  Docks Restaurant & Night Club The  v-1588352904
# 35                               Montecito Restaurant  v-1588352904
# 36                                Penelope Restaurant  v-1588352904
# 37                           Lusso Restaurant and Bar  v-1588352904
# 38                     Pizza Rustica Restaurant & Bar  v-1588352904
# 39  ResoSolutions - Online Restaurant Booking Syst...  v-1588352904
# 40                                Lao Thai Restaurant  v-1588352904
# 41                            Little India Restaurant  v-1588352904
# 42                       Bottom Line Restaurant & Bar  v-1588352904
# 43                       Excellent Chinese Restaurant  v-1588352904
# 44                                 Siempre Restaurant  v-1588352904
# 45                         Matisse Restaurant And Bar  v-1588352904
# 46     Sassafraz | Cafe | Restaurant | Private Events  v-1588352904
# 47                       Flexday At Victor Restaurant  v-1588352904
# 48                                   Union Restaurant  v-1588352904
# 49              Quiznos Canada Restaurant Corporation  v-1588352904
#
#    venuePage.id
# 0           NaN
# 1      68079429
# 2           NaN
# 3           NaN
# 4     136175835
# 5           NaN
# 6           NaN
# 7           NaN
# 8     498556908
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN
# 17          NaN
# 18          NaN
# 19          NaN
# 20          NaN
# 21          NaN
# 22          NaN
# 23          NaN
# 24          NaN
# 25          NaN
# 26          NaN
# 27          NaN
# 28     38118429
# 29          NaN
# 30          NaN
# 31          NaN
# 32          NaN
# 33          NaN
# 34          NaN
# 35    145052232
# 36          NaN
# 37          NaN
# 38          NaN
# 39          NaN
# 40          NaN
# 41     57793907
# 42     35051000
# 43          NaN
# 44          NaN
# 45     83923512
# 46          NaN
# 47          NaN
# 48          NaN
# 49          NaN

# %% [markdown]
# #### Define data of interest

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in df.columns if col.startswith('location.')] + ['id']
df_filtered = df.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
df_filtered['categories'] = df_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
df_filtered.columns = [column.split('.')[-1] for column in df_filtered.columns]

df_filtered.head()
# Out:
#                            name           categories          address  cc  \
# 0                360 Restaurant             Wine Bar   301 Front St W  CA
# 1             Arriba Restaurant           Restaurant  1 Blue Jays Way  CA
# 2  Aroma Fine Indian Restaurant    Indian Restaurant   287 King St. W  CA
# 3         Sightlines Restaurant  American Restaurant    Rogers Centre  CA
# 4        Azure Restaurant & Bar           Restaurant   225 Front St W  CA
#
#       city country                         crossStreet  distance  \
# 0  Toronto  Canada                     301 Front St. W       230
# 1  Toronto  Canada        inside the Renaissance Hotel       319
# 2  Toronto  Canada                         at John St.       710
# 3  Toronto  Canada                                 NaN       345
# 4  Toronto  Canada  in InterContinental Toronto Centre       421
#
#                                     formattedAddress  \
# 0  [301 Front St W (301 Front St. W), Toronto ON ...
# 1  [1 Blue Jays Way (inside the Renaissance Hotel...
# 2  [287 King St. W (at John St.), Toronto ON M5V ...
# 3                [Rogers Centre, Toronto ON, Canada]
# 4  [225 Front St W (in InterContinental Toronto C...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.64253731714456...  43.642537 -79.387042
# 1  [{'label': 'display', 'lat': 43.64147925628281...  43.641479 -79.389074
# 2  [{'label': 'display', 'lat': 43.64646252150344...  43.646463 -79.389644
# 3  [{'label': 'display', 'lat': 43.64163507221119...  43.641635 -79.389365
# 4  [{'label': 'display', 'lat': 43.64474919591934...  43.644749 -79.385113
#
#              neighborhood postalCode state                        id
# 0                     NaN    M5V 2T6    ON  4ad4c05cf964a520dff520e3
# 1                     NaN    M5V 1J4    ON  4ad4c060f964a5208af720e3
# 2                     NaN    M5V 1J5    ON  4aef8854f964a5201cd921e3
# 3                     NaN        NaN    ON  4bc3ad5e461576b0db037f32
# 4  Entertainment District    M5V 2X3    ON  4b223f5af964a520ba4424e3

# %% [markdown]
# #### Review and visualize data collected into dataframe

# %%
df_filtered.name
# Out:
# 0                                        360 Restaurant
# 1                                     Arriba Restaurant
# 2                          Aroma Fine Indian Restaurant
# 3                                 Sightlines Restaurant
# 4                                Azure Restaurant & Bar
# 5                               Victor Restaurant & Bar
# 6                        The Hot House Restaurant & Bar
# 7                    Sky Dragon Chinese Restaurant 龍翔酒樓
# 8                                 Victoria's Restaurant
# 9                       Hemispheres Restaurant & Bistro
# 10                       Goldstone Noodle Restaurant 金石
# 11                                    Evviva Restaurant
# 12                               Rol San Restaurant 龍笙棧
# 13                        Micheal's Restaurant and Deli
# 14                        Green Tea Restaurant Downtown
# 15                      Gonoe Sushi Japanese Restaurant
# 16                   Some Time BBQ Grill Restaurant 碳烤屋
# 17                             Restaurant at Number One
# 18                    Kensington Cornerstone Restaurant
# 19                   North-East Chinese Restaurant 華北美食
# 20                             Ka Chi Korean Restaurant
# 21                              Swatow Restaurant 汕頭小食家
# 22                                       Edo Restaurant
# 23                             New Sky Restaurant 小沙田食家
# 24                                Restaurant | Adelaide
# 25              Tasty's Caribbean Restaurant & Catering
# 26               Ten Restaurant & Wine Bar, Port credit
# 27                        Ito Sushi & Noodle Restaurant
# 28                                    SCHOOL Restaurant
# 29                                   Windows Restaurant
# 30                             Fune Japanese Restaurant
# 31                                    Studio Restaurant
# 32                          Cottage Restaurant & Lounge
# 33                              The Lakeview Restaurant
# 34                    Docks Restaurant & Night Club The
# 35                                 Montecito Restaurant
# 36                                  Penelope Restaurant
# 37                             Lusso Restaurant and Bar
# 38                       Pizza Rustica Restaurant & Bar
# 39    ResoSolutions - Online Restaurant Booking Syst...
# 40                                  Lao Thai Restaurant
# 41                              Little India Restaurant
# 42                         Bottom Line Restaurant & Bar
# 43                         Excellent Chinese Restaurant
# 44                                   Siempre Restaurant
# 45                           Matisse Restaurant And Bar
# 46       Sassafraz | Cafe | Restaurant | Private Events
# 47                         Flexday At Victor Restaurant
# 48                                     Union Restaurant
# 49                Quiznos Canada Restaurant Corporation
# Name: name, dtype: object

# %%
toronto_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around downtown Toronto

# add a red circle marker to represent your brewery (distribution point)
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Your Brewery',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(toronto_map)

# add the nearby restaurants as blue circle markers
for lat, lng, label in zip(df_filtered.lat, df_filtered.lng, df_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(toronto_map)

# display map
toronto_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Cluster the restaurants

# %%
import matplotlib.pyplot as plt # plotting library
# backend for rendering plots within the browser
# %matplotlib inline 

from sklearn.cluster import KMeans 
from sklearn.datasets.samples_generator import make_blobs

# %%
df_filtered.head()
# Out:
#                            name           categories          address  cc  \
# 0                360 Restaurant             Wine Bar   301 Front St W  CA
# 1             Arriba Restaurant           Restaurant  1 Blue Jays Way  CA
# 2  Aroma Fine Indian Restaurant    Indian Restaurant   287 King St. W  CA
# 3         Sightlines Restaurant  American Restaurant    Rogers Centre  CA
# 4        Azure Restaurant & Bar           Restaurant   225 Front St W  CA
#
#       city country                         crossStreet  distance  \
# 0  Toronto  Canada                     301 Front St. W       230
# 1  Toronto  Canada        inside the Renaissance Hotel       319
# 2  Toronto  Canada                         at John St.       710
# 3  Toronto  Canada                                 NaN       345
# 4  Toronto  Canada  in InterContinental Toronto Centre       421
#
#                                     formattedAddress  \
# 0  [301 Front St W (301 Front St. W), Toronto ON ...
# 1  [1 Blue Jays Way (inside the Renaissance Hotel...
# 2  [287 King St. W (at John St.), Toronto ON M5V ...
# 3                [Rogers Centre, Toronto ON, Canada]
# 4  [225 Front St W (in InterContinental Toronto C...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.64253731714456...  43.642537 -79.387042
# 1  [{'label': 'display', 'lat': 43.64147925628281...  43.641479 -79.389074
# 2  [{'label': 'display', 'lat': 43.64646252150344...  43.646463 -79.389644
# 3  [{'label': 'display', 'lat': 43.64163507221119...  43.641635 -79.389365
# 4  [{'label': 'display', 'lat': 43.64474919591934...  43.644749 -79.385113
#
#              neighborhood postalCode state                        id
# 0                     NaN    M5V 2T6    ON  4ad4c05cf964a520dff520e3
# 1                     NaN    M5V 1J4    ON  4ad4c060f964a5208af720e3
# 2                     NaN    M5V 1J5    ON  4aef8854f964a5201cd921e3
# 3                     NaN        NaN    ON  4bc3ad5e461576b0db037f32
# 4  Entertainment District    M5V 2X3    ON  4b223f5af964a520ba4424e3

# %% [markdown]
# #### Create new dataframe with essential data

# %%
df_refined = df_filtered[['name','lat','lng']]
df_refined.head()
# Out:
#                            name        lat        lng
# 0                360 Restaurant  43.642537 -79.387042
# 1             Arriba Restaurant  43.641479 -79.389074
# 2  Aroma Fine Indian Restaurant  43.646463 -79.389644
# 3         Sightlines Restaurant  43.641635 -79.389365
# 4        Azure Restaurant & Bar  43.644749 -79.385113

# %% [markdown]
# #### Initialize K-means

# %%
# set number of clusters
kclusters = 5

kl_clustering = df_refined.drop(['name'],1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(kl_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:49]
# Out:
# array([2, 2, 2, 2, 2, 2, 0, 3, 0, 4, 3, 2, 3, 3, 3, 2, 3, 0, 3, 3, 3, 3,
#        2, 3, 0, 3, 2, 2, 1, 2, 2, 4, 4, 1, 0, 2, 2, 0, 2, 0, 1, 2, 0, 2,
#        2, 4, 4, 2, 1], dtype=int32)

# %% [markdown]
# #### Add cluster labels

# %%
df_refined.insert(0, 'Cluster Labels', kmeans.labels_)

df_refined.head()
# Out:
#    Cluster Labels                          name        lat        lng
# 0               2                360 Restaurant  43.642537 -79.387042
# 1               2             Arriba Restaurant  43.641479 -79.389074
# 2               2  Aroma Fine Indian Restaurant  43.646463 -79.389644
# 3               2         Sightlines Restaurant  43.641635 -79.389365
# 4               2        Azure Restaurant & Bar  43.644749 -79.385113

# %% [markdown]
# #### Sort venues by cluster

# %%
# sort the results by Cluster Labels
print(df_refined.shape)
df_refined.sort_values(["Cluster Labels"], inplace=True)
df_refined
# Out:
# (50, 4)
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
#     Cluster Labels                                               name  \
# 24               0                              Restaurant | Adelaide
# 17               0                           Restaurant at Number One
# 34               0                  Docks Restaurant & Night Club The
# 39               0  ResoSolutions - Online Restaurant Booking Syst...
# 8                0                              Victoria's Restaurant
# 6                0                     The Hot House Restaurant & Bar
# 37               0                           Lusso Restaurant and Bar
# 42               0                       Bottom Line Restaurant & Bar
# 40               1                                Lao Thai Restaurant
# 33               1                            The Lakeview Restaurant
# 28               1                                  SCHOOL Restaurant
# 48               1                                   Union Restaurant
# 43               2                       Excellent Chinese Restaurant
# 38               2                     Pizza Rustica Restaurant & Bar
# 26               2             Ten Restaurant & Wine Bar, Port credit
# 36               2                                Penelope Restaurant
# 35               2                               Montecito Restaurant
# 44               2                                 Siempre Restaurant
# 30               2                           Fune Japanese Restaurant
# 47               2                       Flexday At Victor Restaurant
# 29               2                                 Windows Restaurant
# 27               2                      Ito Sushi & Noodle Restaurant
# 41               2                            Little India Restaurant
# 0                2                                     360 Restaurant
# 22               2                                     Edo Restaurant
# 1                2                                  Arriba Restaurant
# 2                2                       Aroma Fine Indian Restaurant
# 3                2                              Sightlines Restaurant
# 4                2                             Azure Restaurant & Bar
# 5                2                            Victor Restaurant & Bar
# 11               2                                  Evviva Restaurant
# 15               2                    Gonoe Sushi Japanese Restaurant
# 49               2              Quiznos Canada Restaurant Corporation
# 18               3                  Kensington Cornerstone Restaurant
# 25               3            Tasty's Caribbean Restaurant & Catering
# 21               3                            Swatow Restaurant 汕頭小食家
# 20               3                           Ka Chi Korean Restaurant
# 19               3                 North-East Chinese Restaurant 華北美食
# 7                3                 Sky Dragon Chinese Restaurant 龍翔酒樓
# 12               3                             Rol San Restaurant 龍笙棧
# 10               3                     Goldstone Noodle Restaurant 金石
# 16               3                 Some Time BBQ Grill Restaurant 碳烤屋
# 23               3                           New Sky Restaurant 小沙田食家
# 13               3                      Micheal's Restaurant and Deli
# 14               3                      Green Tea Restaurant Downtown
# 32               4                        Cottage Restaurant & Lounge
# 45               4                         Matisse Restaurant And Bar
# 46               4     Sassafraz | Cafe | Restaurant | Private Events
# 9                4                    Hemispheres Restaurant & Bistro
# 31               4                                  Studio Restaurant
#
#           lat        lng
# 24  43.649563 -79.380590
# 17  43.639044 -79.377653
# 34  43.641806 -79.354171
# 39  43.642566 -79.375255
# 8   43.649298 -79.376431
# 6   43.648824 -79.373702
# 37  43.638094 -79.380666
# 42  43.646286 -79.378086
# 40  43.642849 -79.427544
# 33  43.649435 -79.420390
# 28  43.637775 -79.424297
# 48  43.645860 -79.419532
# 43  43.639240 -79.392278
# 38  43.644919 -79.391844
# 26  43.639632 -79.388051
# 36  43.646637 -79.388568
# 35  43.647644 -79.391069
# 44  43.643127 -79.392296
# 30  43.648514 -79.386457
# 47  43.645652 -79.391123
# 29  43.641535 -79.389271
# 27  43.644809 -79.387696
# 41  43.650319 -79.388998
# 0   43.642537 -79.387042
# 22  43.642706 -79.385405
# 1   43.641479 -79.389074
# 2   43.646463 -79.389644
# 3   43.641635 -79.389365
# 4   43.644749 -79.385113
# 5   43.645634 -79.391125
# 11  43.641580 -79.383456
# 15  43.639014 -79.385914
# 49  43.645459 -79.391797
# 18  43.652803 -79.399958
# 25  43.656794 -79.399251
# 21  43.653866 -79.398334
# 20  43.654307 -79.399277
# 19  43.653185 -79.396677
# 7   43.652783 -79.398174
# 12  43.654318 -79.398650
# 10  43.652278 -79.398039
# 16  43.655874 -79.393826
# 23  43.655337 -79.398897
# 13  43.647289 -79.403493
# 14  43.652488 -79.397501
# 32  43.662770 -79.376894
# 45  43.670574 -79.384856
# 46  43.670342 -79.391041
# 9   43.654884 -79.385931
# 31  43.661500 -79.379319

# %% [markdown]
# #### Visualize clusters on map of Toronto

# %%
# create map
map_clusters = folium.Map(location=[43.6409668, -79.3851702], zoom_start=13)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, name, cluster in zip(df_refined['lat'], df_refined['lng'], df_refined['name'], df_refined['Cluster Labels']):
    label = folium.Popup(str(name) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.5).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Results
# The clustering of 50 restaurants in downtown Toronto was able to provide five distinct groupings, one for each day of the week, that will allow the brewery to optimize its daily sales route based on distance from the brewery (distribution point). The five cluster are separated geographially (based on latitude / longitutde data) and denoted by different color coding. The overall objective of this project was achieved, likely providing value to the brewery owner by decreasing planning/experimentation time and decreasing unnecessary costs due to poor delivery route selection.

# %% [markdown]
# ## Discussion
# The results of intial data collection provided unexpectedly clear dileniations in the geographic spacing of the restaurants. This made clustering the venues much easier and the results more expected. This outcome can not be expected in most other situations or cities. A larger collection or venues over a larger radius may have provided more interesting results to observe and with which to experiment. This can be considered a proof of concept, for which the concept proves effective on a small scale.
#
# There are additional variables can be added to make the route selection more complex, and possibly more effective, such as traffic pattern along the route, hours of business for the venues, and average size of the weekly delivery for each cluster. Since one major constraint for the brewery is its single delivery truck, the clustering data does not provide avergage delivery size, per beer case or keg, which would likely influence the route selection and the number of return trips to the brewery on a single day.

# %% [markdown]
# ## Conclusion
# This proof of concept was effective on a small scale for determining an optimum sales route, by day of the week, for a small brewery in downtown Toronto. The clusters were cleary distingushed by geographic location and color. The objective of this project was to provide a model for a potential delivery/sales route for the brewery owner's information and planning purposes. Once the owner gathers more information, develops sales accounts, and increases the size of his distribution and delivery capacity, even greater value can be gleaned from a k-means clustering exercise such as this one.
#
# The target audience for this type of project is sales representatives and organizations engaged in all types of commerce and distribution. Collecting location data and clustering select data can optimize a single sales representative's daily sales route, as well as improving an entire beverage distributor's bottom-line by reducing items such as the following: cost of gas; wear and tear on trucks; accidents on the road; and driver over-time pay. This one project demonstrated the successful execution of a concept that can be broadened in size and variables to provide value for many different businesses.
